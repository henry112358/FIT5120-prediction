# %% [markdown]
# * make prediction on 2018
# * 1.total amount in KG
# * 2.percentlie rank

# %%
import pandas as pd
import numpy as np 

from sklearn.linear_model import LinearRegression, RidgeCV 

from sklearn.linear_model import Ridge

# %%
data = pd.read_csv("emission_train.csv", encoding = "ISO-8859-1")

# %%
len(data)
# Out:
# 21660

# %%
test = pd.read_csv("emission_test.csv", encoding = "ISO-8859-1")

# %%
test.head()
# Out:
#   report_year  facility_id jurisdiction_code        facility_name  \
# 0   2017/2018       549268               VIC  DEALS ROAD LANDFILL
# 1   2017/2019       549268               VIC  DEALS ROAD LANDFILL
# 2   2017/2020       549268               VIC  DEALS ROAD LANDFILL
# 3   2017/2021       549268               VIC  DEALS ROAD LANDFILL
# 4   2017/2022       549268               VIC  DEALS ROAD LANDFILL
#
#           registered_business_name              primary_anzsic_class_name  \
# 0  A.J. BAXTER PROPRIETARY LIMITED  Waste Treatment and Disposal Services
# 1  A.J. BAXTER PROPRIETARY LIMITED  Waste Treatment and Disposal Services
# 2  A.J. BAXTER PROPRIETARY LIMITED  Waste Treatment and Disposal Services
# 3  A.J. BAXTER PROPRIETARY LIMITED  Waste Treatment and Disposal Services
# 4  A.J. BAXTER PROPRIETARY LIMITED  Waste Treatment and Disposal Services
#
#    substance_id                      substance_name  air_total_emission_kg  \
# ...

# %%
#select column needed for modeling:

# %%
list(data)
# Out:
# ['report_year',
#  'facility_id',
#  'jurisdiction_code',
#  'facility_name',
#  'registered_business_name',
#  'primary_anzsic_class_name',
#  'substance_id',
#  'substance_name',
#  'air_total_emission_kg',
#  'suburb',
#  'state',
#  'postcode',
#  'latitude',
#  'longitude',
#  'report_year_1',
#  'postalcode_2']

# %%
x = data[['facility_id',  'substance_id',  'report_year_1', 'postalcode_2']]

# %%
y= data["air_total_emission_kg"]

# %%
x1= test[['facility_id',  'substance_id',  'report_year_1', 'postalcode_2']]

# %%
x_combine_2 =  pd.get_dummies(x_combine)

# %%
x_rr = x_combine_2[x_combine_2["report_year_1"]<11]

# %%
len(x_rr)
# Out:
# 21660

# %%
x1_rr = x_combine_2[x_combine_2["report_year_1"]==11]

# %%
ridge.fit(x_rr,y)
# Out:
# Ridge(alpha=10000, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
ridge = Ridge(alpha =10000 )

# %%
y.head()
# Out:
# 0     99051.022840
# 1    135360.298200
# 2      2571.845666
# 3      2707.205964
# 4      1620.007993
# Name: air_total_emission_kg, dtype: float64

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor()

# %%
rf.fit(x,y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
rf.predict(x1)
# Out:
# array([  1.04578557e+05,   1.19435453e+05,   1.60270157e+03, ...,
#          8.88491000e+02,   8.91252200e+02,   1.04237100e+02])

# %%
rf.predict(x1)
prediction = rf.predict(x1)
prediction = pd.DataFrame(prediction,columns=["rf_pred"])
rf_pred=10**prediction
 
prediction.to_csv("rf_predict.csv",index=False)

# %%
## pr rank

# %%
data = pd.read_csv("emission_train.csv", encoding = "ISO-8859-1")

# %%
predict = pd.read_csv("emission_predicted.csv", encoding = "ISO-8859-1")

# %%
data["pr_rank"] =

# %%
data["substance_name"].value_counts().index.tolist()
# Out:
# ['Carbon monoxide',
#  'Oxides of Nitrogen',
#  'Sulfur dioxide',
#  'Particulate Matter ?10.0 \x91m (PM10)',
#  'Particulate Matter ?2.5 \x91m (PM2.5)']

# %%
data["rank"] =  data.groupby('substance_name')['air_total_emission_kg'].rank(ascending=False)

# %%
data["count"] =  data.groupby('substance_name')['air_total_emission_kg'].rank(ascending=False)
# Out:
#       report_year  facility_id jurisdiction_code  \
# 0       2016/2017       549268               VIC
# 1       2016/2017       549268               VIC
# 2       2016/2017       549268               VIC
# 3       2016/2017       549268               VIC
# 4       2016/2017       549268               VIC
# 5       2016/2017       524810               VIC
# 6       2016/2017       524810               VIC
# 7       2016/2017       524810               VIC
# 8       2016/2017       524810               VIC
# 9       2016/2017       524810               VIC
# 10      2016/2017       526496               VIC
# 11      2016/2017       526496               VIC
# 12      2016/2017       526496               VIC
# 13      2016/2017       526496               VIC
# 14      2016/2017       526496               VIC
# 15      2016/2017       534628               VIC
# 16      2016/2017       534628               VIC
# 17      2016/2017       534628               VIC
# ...

# %%
data["pr_rank"] = data["rank"]/4537

# %%
data.head()
# Out:
#   report_year  facility_id jurisdiction_code        facility_name  \
# 0   2016/2017       549268               VIC  DEALS ROAD LANDFILL
# 1   2016/2017       549268               VIC  DEALS ROAD LANDFILL
# 2   2016/2017       549268               VIC  DEALS ROAD LANDFILL
# 3   2016/2017       549268               VIC  DEALS ROAD LANDFILL
# 4   2016/2017       549268               VIC  DEALS ROAD LANDFILL
#
#           registered_business_name              primary_anzsic_class_name  \
# 0  A.J. BAXTER PROPRIETARY LIMITED  Waste Treatment and Disposal Services
# 1  A.J. BAXTER PROPRIETARY LIMITED  Waste Treatment and Disposal Services
# 2  A.J. BAXTER PROPRIETARY LIMITED  Waste Treatment and Disposal Services
# 3  A.J. BAXTER PROPRIETARY LIMITED  Waste Treatment and Disposal Services
# 4  A.J. BAXTER PROPRIETARY LIMITED  Waste Treatment and Disposal Services
#
#    substance_id                      substance_name  air_total_emission_kg  \
# ...

# %%
predict = pd.read_csv("emission_predicted.csv", encoding = "ISO-8859-1")

# %%
predict.head()
# Out:
#   report_year  facility_id jurisdiction_code        facility_name  \
# 0   2017/2018       549268               VIC  DEALS ROAD LANDFILL
# 1   2017/2019       549268               VIC  DEALS ROAD LANDFILL
# 2   2017/2020       549268               VIC  DEALS ROAD LANDFILL
# 3   2017/2021       549268               VIC  DEALS ROAD LANDFILL
# 4   2017/2022       549268               VIC  DEALS ROAD LANDFILL
#
#           registered_business_name              primary_anzsic_class_name  \
# 0  A.J. BAXTER PROPRIETARY LIMITED  Waste Treatment and Disposal Services
# 1  A.J. BAXTER PROPRIETARY LIMITED  Waste Treatment and Disposal Services
# 2  A.J. BAXTER PROPRIETARY LIMITED  Waste Treatment and Disposal Services
# 3  A.J. BAXTER PROPRIETARY LIMITED  Waste Treatment and Disposal Services
# 4  A.J. BAXTER PROPRIETARY LIMITED  Waste Treatment and Disposal Services
#
#    substance_id                      substance_name  air_total_emission_kg  \
# ...

# %%
predict["rank"] =  predict.groupby('substance_name')['rf_pred'].rank(ascending=False)

# %%
predict["pr_rank"] =  predict["rank"]/389

# %%
data.to_csv("data_till2017.csv",index = False)

# %%
predict.to_csv("prediction.csv",index=False)

# %%
predict.head()
# Out:
#   report_year  facility_id jurisdiction_code        facility_name  \
# 0   2017/2018       549268               VIC  DEALS ROAD LANDFILL
# 1   2017/2019       549268               VIC  DEALS ROAD LANDFILL
# 2   2017/2020       549268               VIC  DEALS ROAD LANDFILL
# 3   2017/2021       549268               VIC  DEALS ROAD LANDFILL
# 4   2017/2022       549268               VIC  DEALS ROAD LANDFILL
#
#           registered_business_name              primary_anzsic_class_name  \
# 0  A.J. BAXTER PROPRIETARY LIMITED  Waste Treatment and Disposal Services
# 1  A.J. BAXTER PROPRIETARY LIMITED  Waste Treatment and Disposal Services
# 2  A.J. BAXTER PROPRIETARY LIMITED  Waste Treatment and Disposal Services
# 3  A.J. BAXTER PROPRIETARY LIMITED  Waste Treatment and Disposal Services
# 4  A.J. BAXTER PROPRIETARY LIMITED  Waste Treatment and Disposal Services
#
#    substance_id                      substance_name  air_total_emission_kg  \
# ...
